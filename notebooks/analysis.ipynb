# %% [markdown]
# # Exploration notebook
#
# STATUS: [CONFIRMED rule] Exploration only. Per CLAUDE.md §14.1, nothing a published figure
# depends on may live here — see `src/diloco_measured/analysis/figures/` for the real figure
# code, which must be runnable headless via `make figures`.
#
# No results exist yet (pre-implementation scaffold).
